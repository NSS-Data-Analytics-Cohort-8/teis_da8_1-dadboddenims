# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
compiled = pd.read_excel('../data/TEIS_IFSP_Teaming_Jan_2022-_Jan_2023.xlsx', sheet_name= 'Compiled_IFSP Teaming')

# %%
intake = pd.read_excel('../data/TEIS_IFSP_Teaming_Jan_2022-_Jan_2023.xlsx', sheet_name= 'All Children with IFSPs')
# Out:
# c:\Users\patri\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
compiled.nunique()
# Out:
# CHILD_ID                4789
# SERVICE_DATE             291
# START_TIME               223
# END_TIME                 291
# SERVICE_SETTING            4
# SERVICE DELIVERY           4
# ADD_USER                 529
# ADD_DATE                9541
# IFSP Teaming ID name       3
# Agency Name               85
# Agency Type                3
# Service Name              23
# dtype: int64

# %%
compiled.head()
# Out:
#    CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 0    457136   2022-01-21   09:30:00  10:30:00  Community-based
# 1    457136   2022-02-15   14:00:00  15:00:00  Community-based
# 2    457585   2022-01-24   08:30:00  09:30:00       Telehealth
# 3    457852   2022-01-12   14:00:00  15:00:00  Community-based
# 4    458051   2022-01-12   12:00:00  13:00:00       Telehealth
#
#     SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 0  Service Delivered         LEECAROL1 2022-01-21 17:54:45
# 1  Service Delivered         LEECAROL1 2022-02-16 05:29:12
# 2  Service Delivered  MILLARDCATHERINE 2022-01-24 14:18:29
# 3  Service Delivered       HEMELKATIE1 2022-01-18 10:39:51
# 4  Service Delivered        JONESMEGAN 2022-01-12 13:46:48
#
#   IFSP Teaming ID name                         Agency Name Agency Type  \
# 0          IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 1             Co-Visit  Siskin Children's Institute (EIRA)        EIRA
# ...

# %%
compiled12 = compiled[compiled['SERVICE_DATE'] <= '2022-12-31']

# %%
compiled12['month'] = compiled12['SERVICE_DATE'].dt.month
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_27276\3536569344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   compiled12['month'] = compiled12['SERVICE_DATE'].dt.month

# %%
compiled12['month'].value_counts()
# Out:
# 3     871
# 11    765
# 5     751
# 2     736
# 10    730
# 8     729
# 9     716
# 1     703
# 4     701
# 6     667
# 12    660
# 7     579
# Name: month, dtype: int64

# %%
compiled_monthly = compiled12[['month', 'IFSP Teaming ID name', 'Service Name', 'CHILD_ID']]

# %%
compiled_monthly.nunique()
# Out:
# month                     12
# IFSP Teaming ID name       3
# Service Name              23
# CHILD_ID                4407
# dtype: int64

# %%
compiled
# Out:
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 0       457136   2022-01-21   09:30:00  10:30:00  Community-based
# 1       457136   2022-02-15   14:00:00  15:00:00  Community-based
# 2       457585   2022-01-24   08:30:00  09:30:00       Telehealth
# 3       457852   2022-01-12   14:00:00  15:00:00  Community-based
# 4       458051   2022-01-12   12:00:00  13:00:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9538    541337   2023-01-10   15:00:00  16:00:00             Home
# 9539    541511   2023-01-19   13:30:00  14:30:00             Home
# 9540    541890   2023-01-19   09:00:00  10:00:00             Home
# 9541    542077   2023-01-30   14:30:00  15:20:00       Telehealth
# 9542    542122   2023-01-30   13:00:00  14:00:00             Home
#
#        SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 0     Service Delivered         LEECAROL1 2022-01-21 17:54:45
# ...

# %%
telehealth = compiled[compiled['SERVICE_SETTING'] == 'Telehealth']

# %%
community = compiled[compiled['SERVICE_SETTING'] == 'Community-based']

# %%
home = compiled[compiled['SERVICE_SETTING'] == 'Home']

# %%
other = compiled[compiled['SERVICE_SETTING'] == 'Other']

# %%
home.head()
# Out:
#     CHILD_ID SERVICE_DATE START_TIME  END_TIME SERVICE_SETTING  \
# 12    459167   2022-01-26   09:00:00  09:30:00            Home
# 13    459167   2022-02-09   09:00:00  10:00:00            Home
# 29    461124   2022-01-04   15:45:00  16:30:00            Home
# 36    462419   2022-01-04   02:30:00  03:30:00            Home
# 38    462527   2022-02-03   01:45:00  02:30:00            Home
#
#      SERVICE DELIVERY         ADD_USER            ADD_DATE  \
# 12  Service Delivered    CARDENHILLARY 2022-03-08 22:20:07
# 13  Service Delivered    CARDENHILLARY 2022-03-08 22:29:53
# 29  Service Delivered      ROGERSKALEY 2022-01-06 17:19:50
# 36  Service Delivered  CONLEYJENNIFER1 2022-01-04 19:43:04
# 38  Service Delivered    VERDISAVANNAH 2022-02-03 16:26:33
#
#    IFSP Teaming ID name                          Agency Name  Agency Type  \
# 12             Co-Visit   LeBonheur EI & Dev (LEAD) (vendor)  Independent
# 13             Co-Visit   LeBonheur EI & Dev (LEAD) (vendor)  Independent
# ...

# %%
telehealth.nunique()
# Out:
# CHILD_ID                2563
# SERVICE_DATE             273
# START_TIME               153
# END_TIME                 238
# SERVICE_SETTING            1
# SERVICE DELIVERY           1
# ADD_USER                 366
# ADD_DATE                3604
# IFSP Teaming ID name       3
# Agency Name               42
# Agency Type                3
# Service Name              18
# dtype: int64

# %% [markdown]
# # Service Setting

# %%
telehealth['IFSP Teaming ID name'].value_counts()
# Out:
# IFSP Meeting    2470
# Co-Visit         775
# IEP Meeting      359
# Name: IFSP Teaming ID name, dtype: int64

# %%
home['IFSP Teaming ID name'].value_counts()
# Out:
# IFSP Meeting    2026
# Co-Visit        1941
# IEP Meeting       43
# Name: IFSP Teaming ID name, dtype: int64

# %%
community['IFSP Teaming ID name'].value_counts()
# Out:
# Co-Visit        871
# IFSP Meeting    246
# IEP Meeting     174
# Name: IFSP Teaming ID name, dtype: int64

# %%
other['IFSP Teaming ID name'].value_counts()
# Out:
# Co-Visit        501
# IFSP Meeting     74
# IEP Meeting      53
# Name: IFSP Teaming ID name, dtype: int64

# %%
child_visits = compiled['CHILD_ID'].value_counts().reset_index().rename(columns = {'index':'child_id', 'CHILD_ID':'visit_count'})

# %%
child_visits
# Out:
#       child_id  visit_count
# 0       494031           48
# 1       480109           34
# 2       501065           32
# 3       481017           31
# 4       494794           31
# ...        ...          ...
# 4784    505287            1
# 4785    505291            1
# 4786    505293            1
# 4787    505307            1
# 4788    542122            1
#
# [4789 rows x 2 columns]

# %%
sns.barplot(data= child_visits, orient='h', y=child_visits['child_id'].head(30).astype(str), x='visit_count')
# Out:
# <Axes: xlabel='visit_count', ylabel='child_id'>

# %%
child_visits['>6'] = child_visits['visit_count'] > 6
child_visits['=6'] = child_visits['visit_count'] == 6
child_visits['<6'] = child_visits['visit_count'] < 6
child_visits
# Out:
#       child_id  visit_count     >6     =6     <6
# 0       494031           48   True  False  False
# 1       480109           34   True  False  False
# 2       501065           32   True  False  False
# 3       481017           31   True  False  False
# 4       494794           31   True  False  False
# ...        ...          ...    ...    ...    ...
# 4784    505287            1  False  False   True
# 4785    505291            1  False  False   True
# 4786    505293            1  False  False   True
# 4787    505307            1  False  False   True
# 4788    542122            1  False  False   True
#
# [4789 rows x 5 columns]

# %%
ifsp_only = compiled[compiled['IFSP Teaming ID name'] == 'IFSP Meeting']

# %%
ifsp_only.nunique()
# Out:
# CHILD_ID                3620
# SERVICE_DATE             275
# START_TIME               167
# END_TIME                 231
# SERVICE_SETTING            4
# SERVICE DELIVERY           3
# ADD_USER                 381
# ADD_DATE                4819
# IFSP Teaming ID name       1
# Agency Name               49
# Agency Type                3
# Service Name              16
# dtype: int64

# %%
covisit_only = compiled[compiled['IFSP Teaming ID name'] == 'Co-Visit']

# %%
covisit_only.nunique()
# Out:
# CHILD_ID                1645
# SERVICE_DATE             284
# START_TIME               184
# END_TIME                 198
# SERVICE_SETTING            4
# SERVICE DELIVERY           3
# ADD_USER                 421
# ADD_DATE                4090
# IFSP Teaming ID name       1
# Agency Name               76
# Agency Type                2
# Service Name              19
# dtype: int64

# %% [markdown]
# # 4. Does participation vary by service type? by service setting? by point of entry?

# %%
compiled
# Out:
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 0       457136   2022-01-21   09:30:00  10:30:00  Community-based
# 1       457136   2022-02-15   14:00:00  15:00:00  Community-based
# 2       457585   2022-01-24   08:30:00  09:30:00       Telehealth
# 3       457852   2022-01-12   14:00:00  15:00:00  Community-based
# 4       458051   2022-01-12   12:00:00  13:00:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9538    541337   2023-01-10   15:00:00  16:00:00             Home
# 9539    541511   2023-01-19   13:30:00  14:30:00             Home
# 9540    541890   2023-01-19   09:00:00  10:00:00             Home
# 9541    542077   2023-01-30   14:30:00  15:20:00       Telehealth
# 9542    542122   2023-01-30   13:00:00  14:00:00             Home
#
#        SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 0     Service Delivered         LEECAROL1 2022-01-21 17:54:45
# ...

# %%
compiled_thin = compiled[['CHILD_ID', 'SERVICE_DATE','SERVICE_SETTING','ADD_USER', 'IFSP Teaming ID name','Agency Name','Agency Type', 'Service Name']]
compiled_thin = compiled_thin.rename(columns = {'CHILD_ID':'child_id', 
                                                'SERVICE_DATE':'service_date',
                                                'SERVICE_SETTING':'service_setting',
                                                'ADD_USER':'add_user', 
                                                'IFSP Teaming ID name':'meeting_type',
                                                'Agency Name':'agency_name',
                                                'Agency Type':'agency_type', 
                                                'Service Name':'service_type'})

# %%
compiled_thin.head()
# Out:
#    child_id service_date  service_setting          add_user  meeting_type  \
# 0    457136   2022-01-21  Community-based         LEECAROL1   IEP Meeting
# 1    457136   2022-02-15  Community-based         LEECAROL1      Co-Visit
# 2    457585   2022-01-24       Telehealth  MILLARDCATHERINE   IEP Meeting
# 3    457852   2022-01-12  Community-based       HEMELKATIE1   IEP Meeting
# 4    458051   2022-01-12       Telehealth        JONESMEGAN  IFSP Meeting
#
#                           agency_name agency_type  \
# 0  Siskin Children's Institute (EIRA)        EIRA
# 1  Siskin Children's Institute (EIRA)        EIRA
# 2  Siskin Children's Institute (EIRA)        EIRA
# 3                               LTVEC        EIRA
# 4             First Steps, Inc (EIRA)        EIRA
#
#                          service_type
# 0  Dev. Therapy Prof - Home/Community
# 1  Dev. Therapy Prof - Home/Community
# 2  Dev. Therapy Prof - Home/Community
# 3  Dev. Therapy Prof - Home/Community
# ...

# %%
intake_clean = intake.drop_duplicates()

# %%
intake_clean
# Out:
#        POE  Child ID Referral Date  Exit Date
# 0       ET    508615    2021-08-06        NaT
# 1       ET    488455    2021-11-02        NaT
# 2       ET    494500    2020-12-14        NaT
# 3       ET    515143    2021-11-22        NaT
# 4       ET    505490    2021-06-15        NaT
# ...     ..       ...           ...        ...
# 138654  UC    541668    2022-11-28        NaT
# 138656  UC    484305    2023-01-09        NaT
# 138661  UC    540987    2022-11-16        NaT
# 138662  UC    526430    2022-07-19 2023-02-13
# 138663  UC    545101    2023-01-17        NaT
#
# [28654 rows x 4 columns]

# %%
intake_clean = intake_clean.rename(columns= {'POE':'poe',
                                             'Child ID':'child_id',
                                             'Referral Date': 'referral_date',
                                             'Exit Date':'exit_date'})

# %%
child_visits2 = compiled['CHILD_ID'].value_counts().reset_index().rename(columns = {'index':'child_id', 'CHILD_ID':'visit_count'})

# %%
intake_visit = pd.merge(intake_clean, child_visits2, how= 'left', on='child_id')

# %%
intake_visit['visit_count'] = intake_visit['visit_count'].fillna(0)

# %%
intake_visit
# Out:
#       poe  child_id referral_date  exit_date  visit_count
# 0      ET    508615    2021-08-06        NaT          1.0
# 1      ET    488455    2021-11-02        NaT          0.0
# 2      ET    494500    2020-12-14        NaT          0.0
# 3      ET    515143    2021-11-22        NaT          1.0
# 4      ET    505490    2021-06-15        NaT          0.0
# ...    ..       ...           ...        ...          ...
# 28649  UC    541668    2022-11-28        NaT          0.0
# 28650  UC    484305    2023-01-09        NaT          0.0
# 28651  UC    540987    2022-11-16        NaT          0.0
# 28652  UC    526430    2022-07-19 2023-02-13          0.0
# 28653  UC    545101    2023-01-17        NaT          0.0
#
# [28654 rows x 5 columns]

# %%
intake_visit[intake_visit['visit_count'] > 0]
# Out:
#       poe  child_id referral_date  exit_date  visit_count
# 0      ET    508615    2021-08-06        NaT          1.0
# 3      ET    515143    2021-11-22        NaT          1.0
# 8      ET    488500    2020-08-27 2022-02-17          1.0
# 14     ET    476451    2020-02-12        NaT          3.0
# 21     ET    486336    2020-07-20        NaT          1.0
# ...    ..       ...           ...        ...          ...
# 28556  UC    508173    2021-07-29 2023-02-02          3.0
# 28568  UC    490975    2020-10-09 2023-02-09          2.0
# 28569  UC    517966    2022-01-25 2023-01-20          1.0
# 28614  UC    521535    2022-02-07 2023-02-07          2.0
# 28617  UC    530408    2022-06-13 2023-02-07          1.0
#
# [6924 rows x 5 columns]

# %%
intake_visit['referral_date'].min()
# Out:
# Timestamp('2019-01-11 00:00:00')

# %%
intake_visit.groupby('poe').sum()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_27276\1540181749.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   intake_visit.groupby('poe').sum()
#        child_id  visit_count
# poe
# ET   2444727541       2411.0
# FT   1433919010       1464.0
# GN   2532344954       1174.0
# MD   2085454766       2650.0
# NW    678711053        569.0
# SC   2194415462       1483.0
# SE   1095771674       1790.0
# SW    756611426        991.0
# UC   1384896971       1174.0

# %%
intake_visit.groupby('poe').median()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_27276\516330069.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   intake_visit.groupby('poe').median()
#      child_id  visit_count
# poe
# ET   510381.0          0.0
# FT   510998.0          0.0
# GN   511782.0          0.0
# MD   512014.5          0.0
# NW   512023.0          0.0
# SC   510648.0          0.0
# SE   510069.0          0.0
# SW   512169.0          0.0
# UC   511032.5          0.0

# %%
intake_visit.groupby('poe').mean()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_27276\1129231094.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   intake_visit.groupby('poe').mean()
#           child_id  visit_count
# poe
# ET   508788.249948     0.501769
# FT   508842.799858     0.519517
# GN   510759.369504     0.236789
# MD   510640.246327     0.648874
# NW   509925.659654     0.427498
# SC   509854.893587     0.344563
# SE   508478.735035     0.830626
# SW   510189.768038     0.668240
# UC   509903.155744     0.432253

# %%
all_intake_sum = intake_visit.groupby('poe').sum().reset_index()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_27276\1003702659.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_intake_sum = intake_visit.groupby('poe').sum().reset_index()

# %% [markdown]
# # aged out

# %%
age_out = intake_visit[intake_visit['exit_date'].notnull()]

# %%
age_out_min_1 = age_out[age_out['visit_count'] > 0].sort_values('visit_count', ascending= False)

# %%
age_out_min_1.shape
# Out:
# (2131, 7)

# %%
age_out_min_1['days_in_program'] = age_out_min_1['exit_date'] - age_out_min_1['referral_date']
age_out_min_1['visit_rate'] = age_out_min_1['days_in_program']/age_out_min_1['visit_count']

# %%
age_out_min_1
# Out:
#       poe  child_id referral_date  exit_date  visit_count days_in_program  \
# 25426  MD    511895    2021-09-29 2022-12-12         31.0        439 days
# 18887  MD    494794    2020-12-17 2022-07-26         31.0        586 days
# 27879  MD    498898    2021-03-02 2023-01-22         29.0        691 days
# 27047  SE    515498    2021-11-30 2023-01-10         27.0        406 days
# 20749  MD    472293    2019-10-28 2022-09-21         23.0       1059 days
# ...    ..       ...           ...        ...          ...             ...
# 18117  FT    495727    2021-01-07 2022-07-26          1.0        565 days
# 18111  FT    482162    2021-08-04 2022-07-30          1.0        360 days
# 18105  FT    486038    2020-07-14 2022-08-19          1.0        766 days
# 18083  FT    502018    2021-04-22 2022-08-19          1.0        484 days
# 28617  UC    530408    2022-06-13 2023-02-07          1.0        239 days
#
#                       visit_rate
# 25426 14 days 03:52:15.483870967
# ...

# %%
age_out_min_1['day_in_program_redux'] = (age_out_min_1['days_in_program']/ np.timedelta64(1, 'D')).astype(int)

# %%
age_out_min_1['visit_rate_redux'] = age_out_min_1['day_in_program_redux']/age_out_min_1['visit_count']

# %%
age_out_min_1 = age_out_min_1.drop(columns = ['days_in_program', 'visit_rate'], axis=0)

# %%
age_out_min_1
# Out:
#       poe  child_id referral_date  exit_date  visit_count  \
# 25426  MD    511895    2021-09-29 2022-12-12         31.0
# 18887  MD    494794    2020-12-17 2022-07-26         31.0
# 27879  MD    498898    2021-03-02 2023-01-22         29.0
# 27047  SE    515498    2021-11-30 2023-01-10         27.0
# 20749  MD    472293    2019-10-28 2022-09-21         23.0
# ...    ..       ...           ...        ...          ...
# 18117  FT    495727    2021-01-07 2022-07-26          1.0
# 18111  FT    482162    2021-08-04 2022-07-30          1.0
# 18105  FT    486038    2020-07-14 2022-08-19          1.0
# 18083  FT    502018    2021-04-22 2022-08-19          1.0
# 28617  UC    530408    2022-06-13 2023-02-07          1.0
#
#        day_in_program_redux  visit_rate_redux
# 25426                   439         14.161290
# 18887                   586         18.903226
# 27879                   691         23.827586
# 27047                   406         15.037037
# ...

# %%
age_out_min_1.groupby('poe').sum()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_27276\2588056458.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   age_out_min_1.groupby('poe').sum()
#       child_id  visit_count  day_in_program_redux  visit_rate_redux
# poe
# ET   195214089        687.0                211286     154752.007143
# FT   122252695        414.0                128620      96770.438095
# GN   115293306        323.0                117057      96753.400000
# MD   133721813        896.0                148408      92209.046952
# NW    63182604        202.0                 67600      52238.216667
# SC   137129364        441.0                136812     107596.412121
# SE   123758511        528.0                128505      86924.897210
# SW    81247152        293.0                 80514      55856.109921
# ...

# %%
age_out_min_1.groupby('poe').mean()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_27276\1698850004.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   age_out_min_1.groupby('poe').mean()
#           child_id  visit_count  day_in_program_redux  visit_rate_redux
# poe
# ET   496727.961832     1.748092            537.623410        393.771011
# FT   498990.591837     1.689796            524.979592        394.981380
# GN   499105.220779     1.398268            506.740260        418.845887
# MD   497107.111524     3.330855            551.702602        342.784561
# NW   497500.818898     1.590551            532.283465        411.324541
# SC   500472.131387     1.609489            499.313869        392.687635
# SE   497022.132530     2.120482            516.084337        349.095973
# ...

# %%
age_out_min_1.groupby('poe').median()
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_27276\494866915.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   age_out_min_1.groupby('poe').median()
#      child_id  visit_count  day_in_program_redux  visit_rate_redux
# poe
# ET   498352.0          1.0                 482.0        337.000000
# FT   498592.0          1.0                 480.0        320.000000
# GN   500452.0          1.0                 481.0        364.000000
# MD   499071.0          1.0                 510.0        279.000000
# NW   499010.0          1.0                 455.0        350.000000
# SC   503849.0          1.0                 437.0        345.333333
# SE   500508.0          1.0                 458.0        276.000000
# SW   502112.0          1.0                 402.0        273.000000
# ...

# %%
intake_visit_bool = intake_visit

# %%
intake_visit_bool['min_1'] = intake_visit_bool['visit_count'] > 0

# %%
intake_visit_bool['over_6'] = intake_visit_bool['visit_count'] >6

# %%
sns.barplot(intake_visit_bool, y = 'min_1')
# Out:
# <Axes: ylabel='min_1'>

# %%
sns.barplot(intake_visit_bool, y='over_6')
# Out:
# <Axes: ylabel='over_6'>

# %%
ivb_poe = intake_visit_bool['poe'].value_counts().reset_index().rename(columns = {'index':'poe','poe':'num_child_id'})

# %%
ivb_poe
# Out:
#   poe  num_child_id
# 0  GN          4958
# 1  ET          4805
# 2  SC          4304
# 3  MD          4084
# 4  FT          2818
# 5  UC          2716
# 6  SE          2155
# 7  SW          1483
# 8  NW          1331

# %%
poe_data = pd.merge(ivb_poe, aom_one_2, on='poe')

# %%
poe_data
# Out:
#   poe  num_child_id  visit_count
# 0  GN          4958        323.0
# 1  ET          4805        687.0
# 2  SC          4304        441.0
# 3  MD          4084        896.0
# 4  FT          2818        414.0
# 5  UC          2716        347.0
# 6  SE          2155        528.0
# 7  SW          1483        293.0
# 8  NW          1331        202.0

# %%
# ax = plt.subplots()
 
# # plotting columns
# ax = sns.barplot(x=poe_data["poe"], y=poe_data['num_child_id'], color='b')
# ax = sns.barplot(x=poe_data["poe"], y=poe_data['visit_count'], color='lightblue')
 
# # renaming the axes
# ax.set(xlabel="x-axis", ylabel="y-axis")
 
# # visualizing illustration
# plt.show()

# %%
sns.barplot(ivb_poe, orient='h', y='poe', x='num_child_id')
# Out:
# <Axes: xlabel='num_child_id', ylabel='poe'>
